# %% [markdown]
# # ⚽ Premier League Analytics & Prediction
#
# Este notebook representa la centralización del análisis exploratorio (EDA) y el llamado a los modelos predictivos divididos modularmente. Tal como lo recomiendan las mejores prácticas de ingeniería de ML, el código base está estructurado a través de scripts `.py` para reutilización, pero se pueden invocar directamente desde aquí para su réplica interactiva.

# %% [markdown]
# ## 1. Análisis Exploratorio (EDA)
# Generamos las gráficas visuales, matrices de correlación y análisis tanto de jugadores como de los eventos subyacentes.

# %%
# Ejecutar EDA de eventos generales del partido
# !python EDA/eda_events.py

# %%
# Ejecutar generación consolidada de plots exploratorios
# !python EDA/generate_eda_plots.py

# %% [markdown]
# ## 2. Entrenamiento de Modelos y Clustering
# Procedemos a ejecutar la fase de aprendizaje no supervisado (agrupamiento de jugadores por perfilamiento base) y la posterior inyección en los modelos predictivos de Random Forest.

# %%
# 2.1 Módulo Probabilístico xG
# !python models/01_xg_model/compare_xg_models.py

# %%
# 2.2 Segmentación Táctica de Jugadores (K-Means & DBSCAN)
# !python models/03_clustering/cluster_players.py

# %%
# 2.3 Entrenamiento avanzado integrado con features agrupadas
# !python models/04_cluster_regression/train_match_regression.py
